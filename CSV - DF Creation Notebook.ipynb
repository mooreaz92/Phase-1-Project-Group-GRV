# %% [markdown]
# # Data Combination over Movie Data Sets (CSV Files)

# %% [markdown]
# The purpose of this notebook is to document the steps taken in order to generate movies_df and studios_df, which will be used for further analysis to make recommendations to Microsoft on where they could enter the original movie production business.
#
# The scope of this excercise is the provided CSV Files:
# - bom.Movie_gross.csv.gz
# - rt.movie_info_tsv.gz
# - rt.reviews.tsv.gz
# - tmdb.movies.csv.gz
# - tn.movie_budgets.csv.gz

# %% [markdown]
# <figure>
#     <img src="Converging Arrows.png"
#          alt="Let's synthesize some data"
#          width="400"
#          height="200">
#     <figcaption><center><bold>Putting it all together</figcaption>
# </figure>

# %% [markdown]
# From the EDA notebook:
#
# The CSV files will contain the relevant financial data needed to make a recommendation to Microsoft. Our key metric will be profitability of movie titles, then profitability by genre, and then identifying people in the movie making labor force would be best for the job (using a mix of both movie profitability and critic reviews)

# %% [markdown]
# ## Master Table Import: "tn.movie_budgets.csv.gz"

# %% [markdown]
# ### *Basic Import*

# %% [markdown]
# For purposes of our combination, we will use 'tn.movie_budgets.csv.gz' as our beginning source of truth, as it contains the most relevant information we are looking to investigate (mainly, domestic and international box office sales and movie budget)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import string
punct = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{}~'

# %%
df_budgets = pd.read_csv("Raw Data/tn.movie_budgets.csv.gz")

# %%
df_budgets.head(2)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875

# %% [markdown]
# Converting the financial data into numbers, release_date info into datetime objects, and creating a 'year' column:

# %%
df_budgets['worldwide_gross'] = df_budgets['worldwide_gross'].str.replace('$', '').str.replace(',', '')
df_budgets['domestic_gross'] = df_budgets['domestic_gross'].str.replace('$', '').str.replace(',', '')
df_budgets['production_budget'] = df_budgets['production_budget'].str.replace('$', '').str.replace(',', '')

df_budgets['worldwide_gross'] = df_budgets['worldwide_gross'].astype(float)
df_budgets['domestic_gross'] = df_budgets['domestic_gross'].astype(float)
df_budgets['production_budget'] = df_budgets['production_budget'].astype(float)

df_budgets['release_date'] = pd.to_datetime(df_budgets['release_date'])

df_budgets['year'] = df_budgets['release_date'].dt.strftime('%Y')
df_budgets['year'] = df_budgets['year'].map(int)

# %% [markdown]
# Since we will be combining additional genre info based off of the title of the movie, we will normalize punctuation use by removing punctuation from all titles in this data source and later data sources:

# %%
transtab = str.maketrans(dict.fromkeys(punct, ''))

df_budgets['movie'] = '|'.join(df_budgets['movie'].tolist()).translate(transtab).split('|')

# %% [markdown]
# We will create a profit calculation, which is worldwide_gross minus the production budget. We will also create a column which calculates the percentage of profit margin

# %%
df_budgets['profit'] = df_budgets['worldwide_gross'] - df_budgets['production_budget']
df_budgets['profit_margin'] = (df_budgets['profit'] / df_budgets['worldwide_gross']) * 100

# %%
df_budgets.head()
# Out:
#    id release_date                                       movie  \
# 0   1   2009-12-18                                      Avatar
# 1   2   2011-05-20  Pirates of the Caribbean On Stranger Tides
# 2   3   2019-06-07                                Dark Phoenix
# 3   4   2015-05-01                      Avengers Age of Ultron
# 4   5   2017-12-15             Star Wars Ep VIII The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  year        profit  \
# 0        425000000.0     760507625.0     2.776345e+09  2009  2.351345e+09
# 1        410600000.0     241063875.0     1.045664e+09  2011  6.350639e+08
# 2        350000000.0      42762350.0     1.497624e+08  2019 -2.002376e+08
# 3        330600000.0     459005868.0     1.403014e+09  2015  1.072414e+09
# 4        317000000.0     620181382.0     1.316722e+09  2017  9.997217e+08
#
#    profit_margin
# 0      84.692106
# 1      60.733080
# 2    -133.703598
# 3      76.436443
# 4      75.925058

# %% [markdown]
# ## Master Table Import Filtering

# %% [markdown]
# A studio like Microsoft will likely put at least 100k into it's projects, so we will filter for budgets above $100k. They will likely not be interested in festivals or other distributions that will not have box office values, so we will filter out movies with zero box office sales. We also are only interested in more modern data, which we will define as anything that was produced later than the 2000's.

# %%
df_budgets = df_budgets[df_budgets['production_budget'] > 100000]
df_budgets = df_budgets[(df_budgets['domestic_gross'] > 1) | (df_budgets['worldwide_gross'] > 1)]
df_budgets = df_budgets[df_budgets['year'] > 2000]

# %% [markdown]
# We will need to join this table with other tables, however there are duplicate values in this data set as multiple movies can share the same title. For purposes of joining, we will join on a new column, movie_and_year, created below:

# %%
df_budgets['year'] = df_budgets['year'].map(str)
df_budgets['movie_and_year'] = df_budgets['movie'] + " - " + df_budgets['year']
df_budgets['year'] = df_budgets['year'].map(int)

# %%
df_budgets[df_budgets.duplicated(['movie_and_year'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, release_date, movie, production_budget, domestic_gross, worldwide_gross, year, profit, profit_margin, movie_and_year]
# Index: []

# %% [markdown]
# The above confirms no duplicate values

# %% [markdown]
# ## Appending Genre using additional IMDB Data

# %% [markdown]
# The SQL information which contains movie title and genres is insufficient at appending associate genres with a movie, so we will import additional data found on the IMBD website (https://datasets.imdbws.com/). These files are rather large so they will be ignored in git pushes

# %%
df_additional = pd.read_csv("Raw Data/title.basics.tsv.gz", sep='\t', encoding='latin1')
df_additional['primaryTitle'] = df_additional['primaryTitle'].map(str)
df_additional = df_additional[df_additional['titleType'] == 'movie']
# Out:
# C:\Users\moore\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
transtab = str.maketrans(dict.fromkeys(punct, ''))

df_additional['primaryTitle'] = '|'.join(df_additional['primaryTitle'].tolist()).translate(transtab).split('|')

# %% [markdown]
# Appending a movie_and_year column:

# %%
df_additional['startYear'] = pd.to_datetime(df_additional['startYear'], errors='coerce')
df_additional['year'] = df_additional['startYear'].dt.strftime('%Y')

df_additional['movie_and_year'] = df_additional['primaryTitle'] + " - " + df_additional['year']

df_additional = df_additional.fillna(0)
df_additional['year'] = df_additional['year'].map(int)

# %% [markdown]
# ## Appending Genre using CSV Data

# %%
df_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3815 entries, 0 to 5678
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3815 non-null   int64
#  1   release_date       3815 non-null   datetime64[ns]
#  2   movie              3815 non-null   object
#  3   production_budget  3815 non-null   float64
#  4   domestic_gross     3815 non-null   float64
#  5   worldwide_gross    3815 non-null   float64
#  6   year               3815 non-null   int64
#  7   profit             3815 non-null   float64
#  8   profit_margin      3815 non-null   float64
#  9   movie_and_year     3815 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(2)
# memory usage:
# 53                         Oz the Great and Powerful       0
# 54                        X-Men: Days of Future Past       0
# 55                          The Amazing Spider-Man 2       0
# 56                                            Cars 2       0
# 57                                              Tron       0
# 58                                              2012       0
# 59       Fantastic Beasts: The Crimes of Grindelwald       0
#
#               startYear endYear runtimeMinutes                      genres  \
# 0   2009-01-01 00:00:00      \N            162    Action,Adventure,Fantasy
# 1   2011-01-01 00:00:00      \N            137    Action,Adventure,Fantasy
# 2                   NaN     NaN            NaN                         NaN
# 3   2015-01-01 00:00:00      \N            141     Action,Adventure,Sci-Fi
# 4                   NaN     NaN            NaN                         NaN
# 5                   NaN     NaN            NaN                         NaN
# 6   2018-01-01 00:00:00      \N            149     Action,Adventure,Sci-Fi
# 7                   NaN     NaN            NaN                         NaN
# 8   2017-01-01 00:00:00      \N            120    Action,Adventure,Fantasy
# 9   2015-01-01 00:00:00      \N            148   Action,Adventure,Thriller
# 10  2012-01-01 00:00:00      \N            164                Action,Drama
# 11  2018-01-01 00:00:00      \N            135     Action,Adventure,Sci-Fi
# 12  2013-01-01 00:00:00      \N            150    Action,Adventure,Western
# 13  2012-01-01 00:00:00      \N            132     Action,Adventure,Sci-Fi
# 14  2010-01-01 00:00:00      \N            100  Adventure,Animation,Comedy
# 15  2007-01-01 00:00:00      \N            139     Action,Adventure,Sci-Fi
# 16  2016-01-01 00:00:00      \N            147     Action,Adventure,Sci-Fi
# 17  2016-01-01 00:00:00      \N            151     Action,Adventure,Sci-Fi
# 18  2012-01-01 00:00:00      \N            169           Adventure,Fantasy
# 19  2009-01-01 00:00:00      \N            153     Action,Adventure,Family
# 20  2013-01-01 00:00:00      \N            161           Adventure,Fantasy
# 21  2014-01-01 00:00:00      \N            144           Adventure,Fantasy
# 22  2017-01-01 00:00:00      \N            136       Action,Crime,Thriller
# 23  2006-01-01 00:00:00      \N            154     Action,Adventure,Sci-Fi
# 24  2017-01-01 00:00:00      \N            129    Action,Adventure,Fantasy
# 25  2008-01-01 00:00:00      \N            106    Action,Adventure,Mystery
# 26  2012-01-01 00:00:00      \N            143     Action,Adventure,Sci-Fi
# 27                  NaN     NaN            NaN                         NaN
# 28  2013-01-01 00:00:00      \N            143     Action,Adventure,Sci-Fi
# 29  2008-01-01 00:00:00      \N            150     Action,Adventure,Family
# 30  2012-01-01 00:00:00      \N            136     Action,Adventure,Sci-Fi
# 31  2012-01-01 00:00:00      \N            131     Action,Adventure,Sci-Fi
# 32  2017-01-01 00:00:00      \N            154     Action,Adventure,Sci-Fi
# 33  2015-01-01 00:00:00      \N            124     Action,Adventure,Sci-Fi
# 34  2012-01-01 00:00:00      \N            106     Action,Adventure,Comedy
# 35  2009-01-01 00:00:00      \N            149     Action,Adventure,Sci-Fi
# 36  2014-01-01 00:00:00      \N            165     Action,Adventure,Sci-Fi
# 37  2006-01-01 00:00:00      \N            104     Action,Adventure,Sci-Fi
# 38  2010-01-01 00:00:00      \N            140      Action,Adventure,Drama
# 39  2005-01-01 00:00:00      \N            187      Action,Adventure,Drama
# 40  2007-01-01 00:00:00      \N            113    Adventure,Family,Fantasy
# 41  2018-01-01 00:00:00      \N            134     Action,Adventure,Sci-Fi
# 42  2018-01-01 00:00:00      \N            118  Action,Adventure,Animation
# 43  2016-01-01 00:00:00      \N            133     Action,Adventure,Sci-Fi
# 44  2016-01-01 00:00:00      \N             97  Adventure,Animation,Comedy
# 45  2010-01-01 00:00:00      \N            103  Adventure,Animation,Comedy
# 46  2013-01-01 00:00:00      \N            130     Action,Adventure,Sci-Fi
# 47  2017-01-01 00:00:00      \N            136     Action,Adventure,Comedy
# 48  2004-01-01 00:00:00      \N            127     Action,Adventure,Sci-Fi
# 49  2010-01-01 00:00:00      \N            108    Adventure,Family,Fantasy
# 50  2010-01-01 00:00:00      \N             99             Fantasy,Musical
# 51  2012-01-01 00:00:00      \N            143   Action,Adventure,Thriller
# 52  2013-01-01 00:00:00      \N            104  Adventure,Animation,Comedy
# 53  2013-01-01 00:00:00      \N            130    Adventure,Family,Fantasy
# 54  2014-01-01 00:00:00      \N            132     Action,Adventure,Sci-Fi
# 55  2014-01-01 00:00:00      \N            142     Action,Adventure,Sci-Fi
# 56  2011-01-01 00:00:00      \N            106  Adventure,Animation,Comedy
# 57  2010-01-01 00:00:00      \N            125     Action,Adventure,Sci-Fi
# 58  2009-01-01 00:00:00      \N            158     Action,Adventure,Sci-Fi
# 59  2018-01-01 00:00:00      \N            134    Adventure,Family,Fantasy
#
#     year_y
# 0   2009.0
# 1   2011.0
# 2      NaN
# 3   2015.0
# 4      NaN
# 5      NaN
# 6   2018.0
# 7      NaN
# 8   2017.0
# 9   2015.0
# 10  2012.0
# 11  2018.0
# 12  2013.0
# 13  2012.0
# 14  2010.0
# 15  2007.0
# 16  2016.0
# 17  2016.0
# 18  2012.0
# 19  2009.0
# 20  2013.0
# 21  2014.0
# 22  2017.0
# 23  2006.0
# 24  2017.0
# 25  2008.0
# 26  2012.0
# 27     NaN
# 28  2013.0
# 29  2008.0
# 30  2012.0
# 31  2012.0
# 32  2017.0
# 33  2015.0
# 34  2012.0
# 35  2009.0
# 36  2014.0
# 37  2006.0
# 38  2010.0
# 39  2005.0
# 40  2007.0
# 41  2018.0
# 42  2018.0
# 43  2016.0
# 44  2016.0
# 45  2010.0
# 46  2013.0
# 47  2017.0
# 48  2004.0
# 49  2010.0
# 50  2010.0
# 51  2012.0
# 52  2013.0
# 53  2013.0
# 54  2014.0
# 55  2014.0
# 56  2011.0
# 57  2010.0
# 58  2009.0
# 59  2018.0

# %%
df_budget_genre.isna().sum()
# Out:
# id                      0
# release_date            0
# movie                   0
# production_budget       0
# domestic_gross          0
# worldwide_gross         0
# year_x                  0
# profit                  0
# profit_margin           0
# movie_and_year          0
# tconst               1019
# titleType            1019
# primaryTitle         1019
# originalTitle        1019
# isAdult              1019
# startYear            1019
# endYear              1019
# runtimeMinutes       1019
# genres               1019
# year_y               1019
# dtype: int64

# %%
from pathlib import Path  
filepath = Path('financial_data.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_budget_genre.to_csv(filepath)
